# %%
import pandas as pd

# %%
countries = pd.read_csv("countries.csv")
countries.head()
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61
# 3         505370.0                   spa                          92.25
# 4         643801.0                   fra                          92.06

# %%
submission = pd.read_csv("sample_submission_NDF.csv")
submission.head()
# Out:
#            id country
# 0  5uwns89zht     NDF
# 1  jtl0dijy2j     NDF
# 2  xx0ulgorjt     NDF
# 3  6c6puo6ix0     NDF
# 4  czqhjk3yfe     NDF

# %%
sessions = pd.read_csv("sessions.csv")
sessions.head()
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %%
test_users = pd.read_csv("test_users.csv")
test_users.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome
# 3   Windows Desktop             IE
# 4       Mac Desktop         Safari

# %%
train_users_ = pd.read_csv("train_users_2.csv")
train_users =train_users_.drop(["country_destination"],axis =1)
train_users_.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
all_users = pd.concat([train_users,test_users])
all_users.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser
# 0        Chrome
# 1        Chrome
# 2            IE
# 3       Firefox
# 4        Chrome

# %% [markdown]
# ### 使用设备

# %%
device = all_users["first_device_type"].value_counts()

# %%
x,y = device.index.tolist(),device.values.tolist(),
from pyecharts import options as opts
from pyecharts.charts import Bar



c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis("使用设备分布",y, )                                                       
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    
    .set_global_opts(
        title_opts=opts.TitleOpts(title="使用设备分布"),
        xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            axislabel_opts={"rotate":-45},
            is_scale=False,
            boundary_gap=True,
        ),
        
  
    )
   
)
c.render("使用设备分布.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\使用设备分布.html'

# %% [markdown]
# ### 中国人去的地区

# %%
device = train_users_.loc[train_users_["language"]=="zh"]

# %%
train_users_no_DNF = train_users_.loc[train_users_["country_destination"]!="NDF"]
#train_users_no_DNF
lan = train_users_no_DNF.groupby("language")["country_destination"].value_counts()

# %%
import json
from pyecharts import options as opts
from pyecharts.charts import Page, Tree
data =[]
x,y = lan.index.tolist(),lan.values.tolist()
for i in range(133):
    a = [{"value":y[i], "name": x[i]},]
    data.extend(a)
    
c = (
     TreeMap()
        .add("用户常去的国家", data)
        .set_global_opts(title_opts=opts.TitleOpts(title="用户常去的国家"))
        .set_series_opts(
            legend_opts=opts.LegendOpts(
                is_show=True
            ),

           label_opts=opts.LabelOpts(position="inside"),
            )
)
c.render("用户常去的国家.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\用户常去的国家.html'

# %%
all_users.isna().any()
# Out:
# id                         False
# date_account_created       False
# timestamp_first_active     False
# date_first_booking          True
# gender                     False
# age                         True
# signup_method              False
# signup_flow                False
# language                   False
# affiliate_channel          False
# affiliate_provider         False
# first_affiliate_tracked     True
# signup_app                 False
# first_device_type          False
# first_browser              False
# dtype: bool

# %% [markdown]
# ### 注册人数增长分析

# %%
all_users["y-m"] = train_users["date_account_created"].str[:7]
all_users["y-m"].head()
# Out:
# 0    2010-06
# 1    2011-05
# 2    2010-09
# 3    2011-12
# 4    2010-09
# Name: y-m, dtype: object

# %%
date_account_created = all_users.groupby("y-m")["id"].count()
date_account_created.head()
# Out:
# y-m
# 2010-01    122
# 2010-02    204
# 2010-03    326
# 2010-04    314
# 2010-05    454
# Name: id, dtype: int64

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
x,y = date_account_created.index.tolist(),date_account_created.values.tolist()

c = (
    Line()
    .add_xaxis(x)
    .add_yaxis("注册人数", y, is_smooth=True,linestyle_opts=opts.LineStyleOpts( width=5),)
    .set_series_opts(
            
            label_opts=opts.LabelOpts(is_show=False),
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="每月新增用户"),
                     xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            axislabel_opts={"rotate":-90},
            is_scale=False,
            boundary_gap=True,
        ),)
)
c.render("注册人数按月增长曲线.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\注册人数按月增长曲线.html'

# %% [markdown]
# ### 性别分析

# %%
all_users["gender"].value_counts()
# Out:
# -unknown-    129480
# FEMALE        77524
# MALE          68209
# OTHER           334
# Name: gender, dtype: int64

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
x =["FEMALE","MALE"]
y =[77524,68209]
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(x,y)],
        radius=["40%", "75%"], center = ["60%", "55%"]
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="airbnb用户性别占比"),
        legend_opts=opts.LegendOpts(
            orient="vertical", pos_top="15%", pos_left="2%"
        ),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render("airbnb用户性别占比.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\airbnb用户性别占比.html'

# %% [markdown]
# ### 年龄分布

# %%
all_users.loc[((all_users["age"]<7)|(all_users["age"]>75)),"age"]=0

# %%
age = all_users.loc[all_users["age"]!=0,"age"]
age = age.dropna()
age_counts = age.value_counts()
age_counts_sort = age_counts.sort_index()

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

x,y = age_counts_sort.index.tolist(),age_counts_sort.values.tolist()

c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis("年龄分布count",y, )                                                       
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    
    .set_global_opts(
        title_opts=opts.TitleOpts(title="年龄分布count"),
        xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
            axislabel_opts={"rotate":0},
            is_scale=False,
            boundary_gap=True,
        ),
        
  
    )
   
)
c.render("年龄分布.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\年龄分布.html'

# %% [markdown]
# ### 地区分布

# %%
local = all_users["language"].value_counts()

# %%
x,y = local.index.tolist(),local.values.tolist()
len(y)
# Out:
# 26

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, TreeMap
data =[]

for i in range(26):
    a = [
        {"value":y[i], "name": x[i]},
    ]
    data.extend(a)

c = (
    TreeMap()
    .add("用户地区分布", data)
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
    .set_series_opts(
        legend_opts=opts.LegendOpts(
            is_show=True
        ),
            
       label_opts=opts.LabelOpts(position="inside"),
        )
)
    
c.render("地区分布.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\地区分布.html'

# %% [markdown]
# ### 不同推广方式+渠道组合

# %%
all_users["channel-provider"] = all_users["affiliate_channel"].str.cat(all_users["affiliate_provider"],sep ="-")

# %%
all_users["channel-provider"].head()
# Out:
# 0    direct-direct
# 1       seo-google
# 2    direct-direct
# 3    direct-direct
# 4    direct-direct
# Name: channel-provider, dtype: object

# %% [markdown]
# ### 不同推广方式+渠道的访问数量

# %%
visit = all_users.groupby(["channel-provider"])["id"].count()
visit
# Out:
# channel-provider
# api-other                      8167
# content-facebook                597
# content-google                 3043
# content-gsp                     455
# content-other                    22
# content-yandex                    1
# direct-direct                181270
# direct-other                    301
# other-craigslist               3475
# other-email-marketing           270
# other-facebook-open-graph       566
# other-meetup                    358
# other-other                    4034
# other-padmapper                 836
# other-wayn                        8
# remarketing-google             1266
# remarketing-yandex                2
# sem-brand-baidu                   8
# sem-brand-bing                 2104
# sem-brand-daum                    1
# sem-brand-google              34273
# sem-brand-naver                   7
# sem-brand-other                  39
# sem-brand-yandex                  7
# sem-non-brand-baidu              18
# sem-non-brand-bing              916
# sem-non-brand-daum                2
# sem-non-brand-facebook            5
# sem-non-brand-google          18092
# sem-non-brand-naver              59
# sem-non-brand-other             144
# sem-non-brand-vast              830
# sem-non-brand-yahoo               1
# sem-non-brand-yandex              8
# seo-baidu                         6
# seo-bing                        699
# seo-facebook                   3394
# seo-google                     9282
# seo-other                       329
# seo-yahoo                       652
# Name: id, dtype: int64

# %% [markdown]
# ### 不同推广方式+渠道的注册数量

# %%
booking = all_users.groupby(["channel-provider"])["date_first_booking"].count()
booking.sort_values(ascending =False)
# Out:
# channel-provider
# direct-direct                59234
# sem-brand-google             10705
# sem-non-brand-google          6516
# api-other                     2785
# seo-google                    2739
# other-craigslist              1616
# other-other                   1508
# seo-facebook                   724
# content-google                 451
# sem-brand-bing                 375
# remarketing-google             368
# sem-non-brand-bing             296
# sem-non-brand-vast             271
# other-padmapper                252
# seo-yahoo                      174
# direct-other                   164
# seo-bing                       162
# seo-other                      156
# other-facebook-open-graph      141
# content-facebook                68
# other-meetup                    46
# sem-non-brand-other             45
# content-gsp                     37
# other-email-marketing           37
# sem-non-brand-naver             15
# sem-non-brand-baidu              5
# sem-brand-baidu                  5
# sem-brand-yandex                 3
# sem-brand-naver                  3
# sem-brand-other                  3
# content-other                    2
# sem-non-brand-daum               1
# sem-non-brand-yandex             1
# content-yandex                   0
# sem-non-brand-yahoo              0
# seo-baidu                        0
# other-wayn                       0
# remarketing-yandex               0
# sem-non-brand-facebook           0
# sem-brand-daum                   0
# Name: date_first_booking, dtype: int64

# %%
booking.sum()
# Out:
# 88908

# %% [markdown]
# ### 不同推广方式+渠道的转化率

# %%
rate = booking/visit
#rate["provider-channel"] = rate["affiliate_channel"].str.cat(rate["affiliate_provider"],sep="-")
rate
# Out:
# channel-provider
# api-other                    0.341006
# content-facebook             0.113903
# content-google               0.148209
# content-gsp                  0.081319
# content-other                0.090909
# content-yandex               0.000000
# direct-direct                0.326772
# direct-other                 0.544850
# other-craigslist             0.465036
# other-email-marketing        0.137037
# other-facebook-open-graph    0.249117
# other-meetup                 0.128492
# other-other                  0.373823
# other-padmapper              0.301435
# other-wayn                   0.000000
# remarketing-google           0.290679
# remarketing-yandex           0.000000
# sem-brand-baidu              0.625000
# sem-brand-bing               0.178232
# sem-brand-daum               0.000000
# sem-brand-google             0.312345
# sem-brand-naver              0.428571
# sem-brand-other              0.076923
# sem-brand-yandex             0.428571
# sem-non-brand-baidu          0.277778
# sem-non-brand-bing           0.323144
# sem-non-brand-daum           0.500000
# sem-non-brand-facebook       0.000000
# sem-non-brand-google         0.360159
# sem-non-brand-naver          0.254237
# sem-non-brand-other          0.312500
# sem-non-brand-vast           0.326506
# sem-non-brand-yahoo          0.000000
# sem-non-brand-yandex         0.125000
# seo-baidu                    0.000000
# seo-bing                     0.231760
# seo-facebook                 0.213318
# seo-google                   0.295087
# seo-other                    0.474164
# seo-yahoo                    0.266871
# dtype: float64

# %%
v_b = pd.merge(visit,booking,on = "channel-provider" )

# %%
v_b.columns=["visit","booking"]

# %%
v_b["rate"] = v_b["booking"]/v_b["visit"]
v_b = v_b.sort_values("booking",ascending = False)
v_b
# Out:
#                             visit  booking      rate
# channel-provider
# direct-direct              181270    59234  0.326772
# sem-brand-google            34273    10705  0.312345
# sem-non-brand-google        18092     6516  0.360159
# api-other                    8167     2785  0.341006
# seo-google                   9282     2739  0.295087
# other-craigslist             3475     1616  0.465036
# other-other                  4034     1508  0.373823
# seo-facebook                 3394      724  0.213318
# content-google               3043      451  0.148209
# sem-brand-bing               2104      375  0.178232
# remarketing-google           1266      368  0.290679
# sem-non-brand-bing            916      296  0.323144
# sem-non-brand-vast            830      271  0.326506
# other-padmapper               836      252  0.301435
# seo-yahoo                     652      174  0.266871
# direct-other                  301      164  0.544850
# seo-bing                      699      162  0.231760
# seo-other                     329      156  0.474164
# other-facebook-open-graph     566      141  0.249117
# content-facebook              597       68  0.113903
# other-meetup                  358       46  0.128492
# sem-non-brand-other           144       45  0.312500
# other-email-marketing         270       37  0.137037
# content-gsp                   455       37  0.081319
# sem-non-brand-naver            59       15  0.254237
# sem-brand-baidu                 8        5  0.625000
# sem-non-brand-baidu            18        5  0.277778
# sem-brand-other                39        3  0.076923
# sem-brand-yandex                7        3  0.428571
# sem-brand-naver                 7        3  0.428571
# content-other                  22        2  0.090909
# sem-non-brand-daum              2        1  0.500000
# sem-non-brand-yandex            8        1  0.125000
# sem-non-brand-facebook          5        0  0.000000
# content-yandex                  1        0  0.000000
# sem-non-brand-yahoo             1        0  0.000000
# seo-baidu                       6        0  0.000000
# sem-brand-daum                  1        0  0.000000
# remarketing-yandex              2        0  0.000000
# other-wayn                      8        0  0.000000

# %%
x,y,z,v = v_b.index.tolist()[:-25],v_b["visit"].values.tolist()[:-25],v_b["booking"].values.tolist()[:-25],v_b["rate"].values.tolist()[:-25],
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line,Scatter



bar = (
    Bar()
    .add_xaxis(x)
    .add_yaxis(
        "访问量",y,label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        
    )
    .add_yaxis(
        "注册量",z,label_opts=opts.LabelOpts(is_show=False),
       
    )
   .set_global_opts(
   # title_opts=opts.TitleOpts(title="手环重量分布top10"),
    xaxis_opts=opts.AxisOpts(
        axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
        axislabel_opts={"rotate":-25},
        is_scale=False,
        boundary_gap=True,
    ),
        
  
    )
    
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="转化率",
            type_="value",
            min_=0,
           # max_=1.00,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value}"),
        )
    )
)

c = (
    Line()
    .add_xaxis(x)
    .add_yaxis("转化率", v,yaxis_index=1,label_opts=opts.LabelOpts(is_show=False),
               markpoint_opts=opts.MarkPointOpts(
                   data=[opts.MarkPointItem(name="自定义标记点",
                       coord=[x[10], y[10]], value=(y[10]
                                                 )
                   )]
               ),
              )

    .set_global_opts(title_opts=opts.TitleOpts(title=""),)
)
   


bar.overlap(c)
grid = (
        Grid()
        .add(bar, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True)
        
    )


grid.render("abc.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\abc.html'

# %%
v_b.to_excel("v_b.xls")

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
x,y1,y2 = v_b.index.tolist()[-15:], v_b["booking"].sort_values().tolist()[-15:],v_b["visit"].sort_values().tolist()[-15:]
c = (
    Bar()
    .add_xaxis(x)
    .add_yaxis("booking", y1,stack="stack2")
    .add_yaxis("visit", y2,stack="stack2")
    .reversal_axis()
    
    .set_series_opts(label_opts=opts.LabelOpts(position = "right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="渠道注册数量"))
)
c.render("渠道注册数量.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\渠道注册数量.html'

# %% [markdown]
# ### 不同营销内容的拉新和转化

# %%
visit = all_users.groupby(["first_affiliate_tracked"])["id"].count()
visit
# Out:
# first_affiliate_tracked
# linked            62064
# local ops            69
# marketing           281
# omg               54859
# product            2353
# tracked-other      6655
# untracked        143181
# Name: id, dtype: int64

# %%
booking = all_users.groupby(["first_affiliate_tracked"])["date_first_booking"].count()
booking
# Out:
# first_affiliate_tracked
# linked           20102
# local ops            9
# marketing           63
# omg              16425
# product            542
# tracked-other     2290
# untracked        47739
# Name: date_first_booking, dtype: int64

# %%
v_b = pd.merge(visit,booking,on = "first_affiliate_tracked" )
v_b.columns=["visit","booking"]

# %%
v_b["rate"] = v_b["booking"]/v_b["visit"]
v_b = v_b.sort_values("booking",ascending = False)
v_b
# Out:
#                           visit  booking      rate
# first_affiliate_tracked
# untracked                143181    47739  0.333417
# linked                    62064    20102  0.323891
# omg                       54859    16425  0.299404
# tracked-other              6655     2290  0.344102
# product                    2353      542  0.230344
# marketing                   281       63  0.224199
# local ops                    69        9  0.130435

# %%
x,y,z,v = v_b.index.tolist(),v_b["visit"].values.tolist(),v_b["booking"].values.tolist(),v_b["rate"].values.tolist()
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line,Scatter



bar = (
    Bar()
    .add_xaxis(x)
    .add_yaxis(
        "访问量",y,label_opts=opts.LabelOpts(is_show=False),
        yaxis_index=0,
        
    )
    .add_yaxis(
        "注册量",z,label_opts=opts.LabelOpts(is_show=False),
       
    )
   .set_global_opts(
   # title_opts=opts.TitleOpts(title="手环重量分布top10"),
    xaxis_opts=opts.AxisOpts(
        axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
        axislabel_opts={"rotate":-25},
        is_scale=False,
        boundary_gap=True,
    ),
        
  
    )
    
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="转化率",
            type_="value",
            min_=0,
           # max_=1.00,
            position="right",
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value}"),
        )
    )
)

c = (
    Line()
    .add_xaxis(x)
    .add_yaxis("转化率", v,yaxis_index=1,label_opts=opts.LabelOpts(is_show=False),
               markpoint_opts=opts.MarkPointOpts(
                   data=[opts.MarkPointItem(name="自定义标记点",
                       coord=[x[1], y[1]], value=(y[1]
                                                 )
                   )]
               ),
              )

    .set_global_opts(title_opts=opts.TitleOpts(title=""),)
)
   


bar.overlap(c)
grid = (
        Grid()
        .add(bar, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True)
        
    )


grid.render("不同营销内容的拉新和转化.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\不同营销内容的拉新和转化.html'

# %% [markdown]
# ### 转化

# %%
sessions.head()
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %% [markdown]
# ### 统计总人数

# %%
users_sum = sessions.groupby(["user_id"])["user_id"].count()
users_sum.shape
# Out:
# (135483,)

# %%
#活跃用户的定义：按照用户的操作总次数，如果用户操作产品大于等于10次，就可以说明用户为偏活跃的用户，
#另一方面说明此用户不是僵尸用户。
user_action_count = sessions.groupby(["user_id"])["user_id"].count()
user_action_count.sort_values()
# Out:
# user_id
# e8d3p4movg       1
# 9h0mpmt605       1
# 1h68rlw2hl       1
# ocp4zuz0t9       1
# 8wuozrt3ow       1
# 1h4pe1wsah       1
# 4rvr0o1yxx       1
# l3khskxias       1
# 2hozeucwn7       1
# 8wp91p0kk0       1
# xiq3huugoh       1
# th1437tcag       1
# lbv24x3jgj       1
# uvystl7itj       1
# ik1wxk26wo       1
# 4i90348yjt       1
# s2qavb275i       1
# mec2cs3cra       1
# p1xu1p81m4       1
# 6i5hs7porx       1
# kyxhb7ilwx       1
# vo2kmezfuk       1
# bq4a10e4wm       1
# ez4wrn35p1       1
# s379kt1d8b       1
# thutj97otv       1
# 7yvi8x4m54       1
# xjcyvroezb       1
# 6kvyu52h3f       1
# kvqg2bdnt3       1
#               ...
# r0rgjqbsvp    1612
# 93dulcecw0    1614
# s5ez13snz0    1685
# e81qfos71y    1701
# 8ikl7vnfa3    1732
# b1io359wpg    1752
# bfiueza7rt    1753
# n4s6g3grzf    1779
# qkbkunyzq7    1780
# r541x78s24    1792
# ejpe95pcyo    1797
# yu5bdalz2b    1811
# j2cvctvqve    1861
# 5vpuk5mssg    1876
# gey51ednme    1919
# e8h4qghxlg    1923
# p1183hxzc4    1938
# 1m6xnhstmb    2019
# vcmr2jh5ix    2085
# a0uhiojrra    2137
# h0cjxc177k    2246
# monrpvx2md    2264
# 9z4gim1s4l    2264
# wyv1imf8qw    2323
# ht8alhs4lt    2335
# wg9413iaux    2362
# l5lgm3w5pc    2424
# mjbl6rrj52    2476
# 0hjoc5q8nf    2644
# mxqbh3ykxl    2722
# Name: user_id, Length: 135483, dtype: int64

# %% [markdown]
# ### 所有用户中的活跃用户数

# %%
user_active = user_action_count[user_action_count>=10]
user_active.shape
# Out:
# (114001,)

# %%
all_users.shape
# Out:
# (275547, 17)

# %%
sessions.shape
# Out:
# (10567737, 6)

# %%
pd_all = pd.merge(sessions,all_users,left_on="user_id",right_on="id")

# %%
pd_all.shape
# Out:
# (10533241, 23)

# %% [markdown]
# ### 注册用户数

# %%
pd_all.groupby(["user_id"])["user_id"].count().shape
# Out:
# (135483,)

# %%
sessions.head()
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %% [markdown]
# ### 下单用户 用户行为中“reservations”为预定（下单）用户数

# %%
reser = sessions.loc[sessions["action_detail"]=="reservations"]
reser.groupby("user_id")["user_id"].count().shape
# Out:
# (10366,)

# %% [markdown]
# ### 实际支付用户 用户行为中“payment_instruments”为支付 用户数

# %%
payment = sessions.loc[sessions["action_detail"]=="payment_instruments"]
payment.groupby("user_id")["user_id"].count().shape
# Out:
# (9018,)

# %% [markdown]
# ### 复购用户 统计进行了“payment_instruments”操作次数大于1次的用户

# %%
repay = sessions.loc[sessions["action_detail"]=="payment_instruments"]
repay
# Out:
#              user_id               action action_type        action_detail  \
# 114525    q83d1akfql  payment_instruments        data  payment_instruments
# 116971    xzulq9d96w  payment_instruments        data  payment_instruments
# 116975    xzulq9d96w  payment_instruments        data  payment_instruments
# 124828    37p6yvgtst  payment_instruments        data  payment_instruments
# 127030    tr5j6nmvs9  payment_instruments        data  payment_instruments
# 130088    pm9dx88fzk  payment_instruments        data  payment_instruments
# 135849    iltmd264ed  payment_instruments        data  payment_instruments
# 135983    iltmd264ed  payment_instruments        data  payment_instruments
# 137053    gndegj3vku  payment_instruments        data  payment_instruments
# 142026    clhi2u9ypw  payment_instruments        data  payment_instruments
# 150031    uuon68m77c  payment_instruments        data  payment_instruments
# 150054    uuon68m77c  payment_instruments        data  payment_instruments
# 150142    uuon68m77c  payment_instruments        data  payment_instruments
# 161373    2sosc7yqts  payment_instruments        data  payment_instruments
# 164524    wu99ikjs6k  payment_instruments        data  payment_instruments
# 164893    wu99ikjs6k  payment_instruments        data  payment_instruments
# 164919    wu99ikjs6k  payment_instruments        data  payment_instruments
# 167142    4x6offuz5h  payment_instruments        data  payment_instruments
# 167426    f2fvm1367h  payment_instruments        data  payment_instruments
# 169075    q6l0vn59fl  payment_instruments        data  payment_instruments
# 173042    v4ibo2vlir  payment_instruments        data  payment_instruments
# 177950    qj496y0vol  payment_instruments        data  payment_instruments
# 177983    qj496y0vol  payment_instruments        data  payment_instruments
# 184013    v4gn17rkjw  payment_instruments        data  payment_instruments
# 184016    v4gn17rkjw  payment_instruments        data  payment_instruments
# 185259    a7xvm9iz1k  payment_instruments        data  payment_instruments
# 185337    snypzfyrt6  payment_instruments        data  payment_instruments
# 185371    snypzfyrt6  payment_instruments        data  payment_instruments
# 185384    snypzfyrt6  payment_instruments        data  payment_instruments
# 185397    snypzfyrt6  payment_instruments        data  payment_instruments
# ...              ...                  ...         ...                  ...
# 10554951  h5wkk7glj3  payment_instruments        data  payment_instruments
# 10554958  h5wkk7glj3  payment_instruments        data  payment_instruments
# 10555535  ebj5yppwtx  payment_instruments        data  payment_instruments
# 10558357  b6jxsqdidf  payment_instruments        data  payment_instruments
# 10558369  b6jxsqdidf  payment_instruments        data  payment_instruments
# 10558550  n2w6mtgbfh  payment_instruments        data  payment_instruments
# 10559125  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559132  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559173  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559274  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559303  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559337  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559346  ltd8uvna4h  payment_instruments        data  payment_instruments
# 10559596  bwd28urrxg  payment_instruments        data  payment_instruments
# 10559748  0wai4cjyn0  payment_instruments        data  payment_instruments
# 10560260  0eg7rigfxc  payment_instruments        data  payment_instruments
# 10560315  0eg7rigfxc  payment_instruments        data  payment_instruments
# 10560345  0eg7rigfxc  payment_instruments        data  payment_instruments
# 10561777  tvyyjfaqet  payment_instruments        data  payment_instruments
# 10563862  cvus4j3bvt  payment_instruments        data  payment_instruments
# 10563928  cvus4j3bvt  payment_instruments        data  payment_instruments
# 10566473  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10566546  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10566555  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10566568  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10566586  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10566604  ozb2z0km6l  payment_instruments        data  payment_instruments
# 10567082  f9a1ncjnrg  payment_instruments        data  payment_instruments
# 10567098  f9a1ncjnrg  payment_instruments        data  payment_instruments
# 10567106  f9a1ncjnrg  payment_instruments        data  payment_instruments
#
#                                device_type  secs_elapsed
# 114525                         iPad Tablet           1.0
# 116971                              iPhone           8.0
# 116975                              iPhone        6788.0
# 124828                           -unknown-       93652.0
# 127030                              iPhone          61.0
# 130088                           -unknown-        7914.0
# 135849                              iPhone      203174.0
# 135983                              iPhone       32076.0
# 137053    Android App Unknown Phone/Tablet        7191.0
# 142026    Android App Unknown Phone/Tablet       25461.0
# 150031                              iPhone       51509.0
# 150054                              iPhone       23410.0
# 150142                              iPhone           3.0
# 161373    Android App Unknown Phone/Tablet        9141.0
# 164524    Android App Unknown Phone/Tablet        8638.0
# 164893    Android App Unknown Phone/Tablet        7609.0
# 164919    Android App Unknown Phone/Tablet        1624.0
# 167142                              iPhone          25.0
# 167426                              iPhone          16.0
# 169075                              iPhone       14304.0
# 173042    Android App Unknown Phone/Tablet        6829.0
# 177950                              iPhone          18.0
# 177983                              iPhone        1066.0
# 184013                              iPhone       23494.0
# 184016                              iPhone           7.0
# 185259    Android App Unknown Phone/Tablet        3941.0
# 185337                           iPodtouch       42490.0
# 185371                           iPodtouch          16.0
# 185384                           iPodtouch         261.0
# 185397                           iPodtouch          58.0
# ...                                    ...           ...
# 10554951                            Tablet        1521.0
# 10554958                            Tablet          89.0
# 10555535                     Android Phone          90.0
# 10558357                            iPhone           6.0
# 10558369                            iPhone           4.0
# 10558550                     Android Phone         602.0
# 10559125                            iPhone           6.0
# 10559132                            iPhone        8837.0
# 10559173                            iPhone        3230.0
# 10559274                            iPhone         155.0
# 10559303                            iPhone        1709.0
# 10559337                            iPhone         958.0
# 10559346                            iPhone       14440.0
# 10559596                     Android Phone        2014.0
# 10559748                            iPhone       51345.0
# 10560260                     Android Phone         478.0
# 10560315                     Android Phone        2289.0
# 10560345                     Android Phone       38168.0
# 10561777                            iPhone       28042.0
# 10563862                     Android Phone         112.0
# 10563928                     Android Phone         230.0
# 10566473                     Android Phone        1132.0
# 10566546                     Android Phone        1258.0
# 10566555                     Android Phone       11014.0
# 10566568                     Android Phone        6659.0
# 10566586                     Android Phone        4202.0
# 10566604                     Android Phone        4808.0
# 10567082                     Android Phone       40978.0
# 10567098                     Android Phone       11270.0
# 10567106                     Android Phone        1994.0
#
# [23483 rows x 6 columns]

# %%
repay_count = repay.groupby("user_id")["user_id"].count()
repay_count[repay_count>=2]
# Out:
# user_id
# 002qnbzfs5    12
# 01exzqnc72     8
# 01kv2ppj25     3
# 01w5zolph1     3
# 02g0fo4l82     3
# 02sjeoorpr     3
# 038y8b0qq7     2
# 03xvfy76e6     3
# 044959ww4h     2
# 04ewjnywy5    12
# 04k5a44j20     9
# 04k9h4hugg     2
# 04kwu8wbay     2
# 04l4ut0j7g     3
# 04xakxmff7     2
# 056qnsw0nz     5
# 056t8rgj4z     3
# 05d3awab7r     3
# 05izk4llqc     2
# 05tho4lf9w     5
# 06x1a2lbm4     4
# 07cqf4apk0     2
# 07f640d79y     2
# 07vdl2ksq3     2
# 086fzy4hbm     2
# 099d06hjwk     2
# 0a1cgxan7s     5
# 0ami1ev8ho     2
# 0b19kbtkvd     5
# 0b3w03mqsq     3
#               ..
# zoq5i6jsh0     2
# zp0an3cv1p     4
# zp0bgz0qjy     2
# zp72rfswko     3
# zp9v2k65xv     6
# zpmjh09spj     4
# zpqx7se1dw     6
# zpx6thxvi7     8
# zq334re75p    22
# zqc95eesk4     4
# zr9f8jwb8v     6
# zrcyih60l2     2
# zrq1gfng4s     2
# zrxsicafbt     2
# zs0pnlqlhh     3
# zsqnbxxjtf     2
# zssal43s1a     5
# ztcd3rmy1i     2
# ztu988r7gi     4
# zubqatnddv    12
# zud66kbg7v     3
# zvi20rdur1     2
# zw6j323xpe     5
# zwm1cd72ik     2
# zwsc7vb5pz     2
# zxpkkcycpj     4
# zxx6dj4qly     3
# zy4osm5l0s     5
# zyef5tbx82     5
# zyqu19zv62     4
# Name: user_id, Length: 4153, dtype: int64

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page
y = [135483,114001,73815,10366,9018, 4153]
r = [100,84.1, 64.7,14.0, 86.7, 46.1]
x = ["总用户人数","活跃用户数","注册用户数" ,"下单用户","实际支付用户","复购用户"]
c = (
    Funnel()
    .add(
        "转化率",
        [list(z) for z in zip(x,y)],
       # label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c}",position="inside",))
)
c.render("转化率漏斗模型图.html")
# Out:
# 'C:\\Users\\hali\\Desktop\\airbnb\\转化率漏斗模型图.html'
